# %% [markdown]
# # Movie Classification

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
movie = pd.read_csv("movies_dataset.csv")

# %%
movie
# Out:
#                      genre_ids      id original_language  \
# 0      [16, 10751, 12, 14, 35]  502356                en
# 1                 [28, 80, 53]  385687                en
# 2                 [53, 27, 14]  713704                en
# 3                [28, 12, 878]  640146                en
# 4                     [28, 53]  552688                en
# ...                        ...     ...               ...
# 11995                     [18]  493622                hi
# 11996              [18, 10749]   75352                hi
# 11997                     [35]  471364                hi
# 11998                       []  143734                hi
# 11999                  [10749]  265289                hi
#
#                                                 overview  popularity  \
# 0      While working underground to fix a water main,...    8374.440
# 1      Over many missions and against impossible odds...    6742.222
# 2      Three siblings find an ancient vinyl that give...    3842.290
# ...

# %%
movie["title"][(movie["release_date"]<="2013-09-05") & (movie["genres"]=="Drama")]
# Out:
# 70                          The Help
# 560                Good Will Hunting
# 563                           Lolita
# 595        The Passion of the Christ
# 815                         Rocky IV
#                     ...
# 11921    Shaadi Karke Phas Gaya Yaar
# 11926                      Tan-Badan
# 11932              Udhaar Ki Zindagi
# 11956                     Dharmputra
# 11995                     The Killer
# Name: title, Length: 347, dtype: object
